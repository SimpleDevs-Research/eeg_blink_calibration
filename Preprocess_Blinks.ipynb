# %%
import pandas as pd
import os

# %%
# Primitives
_DATA_DIR = 'data/P1/'
_EYE_CSV = 'eye.csv'

# %%
eye_df = pd.read_csv(os.path.join(_DATA_DIR, _EYE_CSV))

# %%
eye_df.head(10)
# Out:
#          unix_ms  rel_timestamp  frame       event  gaze_target_world_pos_x  \
# 0  1758744669358       0.000000    267  Activation                 0.000000
# 1  1758744669763       0.000000    267     Eye Hit                -6.128958
# 2  1758744669904       0.000000    268     Eye Hit                -7.424281
# 3  1758744669948       0.020000    269     Eye Hit               -12.773070
# 4  1758744669965       0.039198    270     Eye Hit               -13.723320
# 5  1758744670018       0.091806    271     Eye Hit               -10.116690
# 6  1758744670059       0.132883    272     Eye Hit                -5.680046
# 7  1758744670100       0.173008    273     Eye Hit                -4.362663
# 8  1758744670138       0.210920    274     Eye Hit                -4.155407
# 9  1758744670166       0.239643    275     Eye Hit                -4.096039
#
#    gaze_target_world_pos_y  gaze_target_world_pos_z  gaze_target_screen_pos_x  \
# ...
