# %% [markdown]
# # Cleaning Participants' EEG Columns
#
# This is a script to clean up a participant's EEG data. By cleanup, this operation includes:
#
# 1. Separating blink rows from the EEG rows
# 2. Separating the raw EEG signal columns from the Mind Monitor-processed columns
#
# The expected output are 3 dataframes.
